# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import cv2
camera = cv2.VideoCapture('./test_video_processed.avi')
total_frame_number = camera.get(cv2.CAP_PROP_FRAME_COUNT)
print('Total # of frame:{}'.format(total_frame_number))
# Out:
# Total # of frame:0.0

# %%
(grabbed, frame) = camera.read()

# %%
plt.figure()
plt.imshow(frame)
cv2.imwrite('./figures/Camera1_estimated_occupancy.png', frame)
# Out:
# <img src="data:image/png;base64,..." width="640">
# True
