# %% [markdown]
# # Generate Action_Space_Name

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Parameterized Action Space Name
# * Parameterized action space
#    * 1.a) ramp up time: the time it takes for the actuator to fade to its maximum value
#    * 1.b) hold time: the time it that the actuator holds at the maximum value
#    * 1.c) ramp down time: the time it takes for the actuator to fade to 0
#    * 1.d) maximum brightness
#    * 2) the time gap between the moth starting to fade and the protocell starting to fade
#    * 3) time between activation of each SMA arm on breathing pore
#    * 4) time between activation of each breathing pore
#    * 5a) minimum time to wait before activating background behaviour
#    * 5b) maximum time to wait before activating background behaviour
#    * 6a) time to wait before trying to pick an actuator
#    * 6b) probability of successfully choosing an actuator
#    * 7) time between choosing SMA to actuate
#    * 8a) minimum time to wait before performing sweep
#    * 8b) maximum time to wait before performing sweep

# %%
name_para = ['1.a) ramp up time: the time it takes for the actuator to fade to its maximum value', 
             '1.b) hold time: the time it that the actuator holds at the maximum value', 
             '1.c) ramp down time: the time it takes for the actuator to fade to 0', 
             '1.d) maximum brightness', 
             '2) the time gap between the moth starting to fade and the protocell starting to fade', 
             '3) time between activation of each SMA arm on breathing pore',
             '4) time between activation of each breathing pore', 
             '5a) minimum time to wait before activating background behaviour', 
             '5b) maximum time to wait before activating background behaviour', 
             '6a) time to wait before trying to pick an actuator', 
             '6b) probability of successfully choosing an actuator', 
             '7) time between choosing SMA to actuate', 
             '8a) minimum time to wait before performing sweep', 
             '8b) maximum time to wait before performing sweep']

action_space_name_para = pd.DataFrame({'index': np.arange(len(name_para)), 'actuator_name': name_para})
action_space_name_para.to_csv('action_space_name_parameterized.csv', index=False)

pd.read_csv('action_space_name_parameterized.csv')
# Out:
#                                         actuator_name  index
# 0   1.a) ramp up time: the time it takes for the a...      0
# 1   1.b) hold time: the time it that the actuator ...      1
# 2   1.c) ramp down time: the time it takes for the...      2
# 3                             1.d) maximum brightness      3
# 4   2) the time gap between the moth starting to f...      4
# 5   3) time between activation of each SMA arm on ...      5
# 6   4) time between activation of each breathing pore      6
# 7   5a) minimum time to wait before activating bac...      7
# 8   5b) maximum time to wait before activating bac...      8
# 9   6a) time to wait before trying to pick an actu...      9
# 10  6b) probability of successfully choosing an ac...     10
# 11            7) time between choosing SMA to actuate     11
# 12   8a) minimum time to wait before performing sweep     12
# 13   8b) maximum time to wait before performing sweep     13

# %% [markdown]
# ## Raw Action Space Name
# * Raw actuator action space:
#    * 24 nodes, each of which has 6 SMAs, 1 Moth and 1 LED.

# %%
name_raw = ['sma1_node#1','sma2_node#1','sma3_node#1','sma4_node#1','sma5_node#1','sma6_node#1','light_node#1','moth_node#1',
        'sma1_node#2', 'sma2_node#2', 'sma3_node#2', 'sma4_node#2', 'sma5_node#2', 'sma6_node#2', 'light_node#2', 'moth_node#2',
        'sma1_node#3', 'sma2_node#3', 'sma3_node#3', 'sma4_node#3', 'sma5_node#3', 'sma6_node#3', 'light_node#3', 'moth_node#3',
        'sma1_node#4', 'sma2_node#4', 'sma3_node#4', 'sma4_node#4', 'sma5_node#4', 'sma6_node#4', 'light_node#4', 'moth_node#4',
        'sma1_node#5', 'sma2_node#5', 'sma3_node#5', 'sma4_node#5', 'sma5_node#5', 'sma6_node#5', 'light_node#5', 'moth_node#5',
        'sma1_node#6', 'sma2_node#6', 'sma3_node#6', 'sma4_node#6', 'sma5_node#6', 'sma6_node#6', 'light_node#6', 'moth_node#6',
        'sma1_node#7', 'sma2_node#7', 'sma3_node#7', 'sma4_node#7', 'sma5_node#7', 'sma6_node#7', 'light_node#7', 'moth_node#7',
        'sma1_node#8', 'sma2_node#8', 'sma3_node#8', 'sma4_node#8', 'sma5_node#8', 'sma6_node#8', 'light_node#8', 'moth_node#8',
        'sma1_node#9', 'sma2_node#9', 'sma3_node#9', 'sma4_node#9', 'sma5_node#9', 'sma6_node#9', 'light_node#9', 'moth_node#9',
        'sma1_node#10', 'sma2_node#10', 'sma3_node#10', 'sma4_node#10', 'sma5_node#10', 'sma6_node#10', 'light_node#10', 'moth_node#10',
        'sma1_node#11', 'sma2_node#11', 'sma3_node#11', 'sma4_node#11', 'sma5_node#11', 'sma6_node#11', 'light_node#11', 'moth_node#11',
        'sma1_node#12', 'sma2_node#12', 'sma3_node#12', 'sma4_node#12', 'sma5_node#12', 'sma6_node#12', 'light_node#12', 'moth_node#12',
        'sma1_node#13', 'sma2_node#13', 'sma3_node#13', 'sma4_node#13', 'sma5_node#13', 'sma6_node#13', 'light_node#13', 'moth_node#13',
        'sma1_node#14', 'sma2_node#14', 'sma3_node#14', 'sma4_node#14', 'sma5_node#14', 'sma6_node#14', 'light_node#14', 'moth_node#14',
        'sma1_node#15', 'sma2_node#15', 'sma3_node#15', 'sma4_node#15', 'sma5_node#15', 'sma6_node#15', 'light_node#15', 'moth_node#15',
        'sma1_node#16', 'sma2_node#16', 'sma3_node#16', 'sma4_node#16', 'sma5_node#16', 'sma6_node#16', 'light_node#16', 'moth_node#16',
        'sma1_node#17', 'sma2_node#17', 'sma3_node#17', 'sma4_node#17', 'sma5_node#17', 'sma6_node#17', 'light_node#17', 'moth_node#17',
        'sma1_node#18', 'sma2_node#18', 'sma3_node#18', 'sma4_node#18', 'sma5_node#18', 'sma6_node#18', 'light_node#18', 'moth_node#18',
        'sma1_node#19', 'sma2_node#19', 'sma3_node#19', 'sma4_node#19', 'sma5_node#19', 'sma6_node#19', 'light_node#19', 'moth_node#19',
        'sma1_node#20', 'sma2_node#20', 'sma3_node#20', 'sma4_node#20', 'sma5_node#20', 'sma6_node#20', 'light_node#20', 'moth_node#20',
        'sma1_node#21', 'sma2_node#21', 'sma3_node#21', 'sma4_node#21', 'sma5_node#21', 'sma6_node#21', 'light_node#21', 'moth_node#21',
        'sma1_node#22', 'sma2_node#22', 'sma3_node#22', 'sma4_node#22', 'sma5_node#22', 'sma6_node#22', 'light_node#22', 'moth_node#22',
        'sma1_node#23', 'sma2_node#23', 'sma3_node#23', 'sma4_node#23', 'sma5_node#23', 'sma6_node#23', 'light_node#23', 'moth_node#23',
        'sma1_node#24', 'sma2_node#24', 'sma3_node#24', 'sma4_node#24', 'sma5_node#24', 'sma6_node#24', 'light_node#24', 'moth_node#24']

action_space_name_para = pd.DataFrame({'index': np.arange(len(name_raw)), 'actuator_name': name_raw})
action_space_name_para.to_csv('action_space_name_raw.csv', index=False)

pd.read_csv('action_space_name_raw.csv')
# Out:
#      actuator_name  index
# 0      sma1_node#1      0
# 1      sma2_node#1      1
# 2      sma3_node#1      2
# 3      sma4_node#1      3
# 4      sma5_node#1      4
# 5      sma6_node#1      5
# 6     light_node#1      6
# 7      moth_node#1      7
# 8      sma1_node#2      8
# 9      sma2_node#2      9
# 10     sma3_node#2     10
# 11     sma4_node#2     11
# 12     sma5_node#2     12
# 13     sma6_node#2     13
# 14    light_node#2     14
# 15     moth_node#2     15
# 16     sma1_node#3     16
# 17     sma2_node#3     17
# 18     sma3_node#3     18
# 19     sma4_node#3     19
# 20     sma5_node#3     20
# 21     sma6_node#3     21
# 22    light_node#3     22
# 23     moth_node#3     23
# 24     sma1_node#4     24
# 25     sma2_node#4     25
# 26     sma3_node#4     26
# 27     sma4_node#4     27
# 28     sma5_node#4     28
# 29     sma6_node#4     29
# ..             ...    ...
# 162   sma3_node#21    162
# 163   sma4_node#21    163
# 164   sma5_node#21    164
# ...
